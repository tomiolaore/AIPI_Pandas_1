# %%
import pandas as pd

# %%
df = pd.read_csv(r"C:\Users\AICAMP\Downloads\SAT College Board 2010 School Level Results.csv")

# %%
df
# Out:
#         DBN                                        School Name  \
# 0    01M292     Henry Street School for International Studies
# 1    01M448               University Neighborhood High School
# 2    01M450                   East Side Community High School
# 3    01M458                      SATELLITE ACADEMY FORSYTH ST
# 4    01M509                                  CMSP HIGH SCHOOL
# 5    01M515           Lower East Side Preparatory High School
# 6    01M539       New Explorations into Sci, Tech and Math HS
# 7    01M650                              CASCADES HIGH SCHOOL
# 8    01M696                    BARD HIGH SCHOOL EARLY COLLEGE
# 9    02M047                       AMERICAN SIGN LANG ENG DUAL
# 10   02M288                       FOOD AND FNANCE HIGH SCHOOL
# 11   02M294                     HIGH SCHOOL FOR HIST AND COMM
# 12   02M296             High School of Hospitality Management
# 13   02M298                                  PACE HIGH SCHOOL
# ...

# %%
df2 = pd.read_csv(r"C:\Users\AICAMP\Downloads\2012 SAT Results.csv")

# %%
df2
# Out:
#         DBN                                        SCHOOL NAME  \
# 0    01M292      HENRY STREET SCHOOL FOR INTERNATIONAL STUDIES
# 1    01M448                UNIVERSITY NEIGHBORHOOD HIGH SCHOOL
# 2    01M450                         EAST SIDE COMMUNITY SCHOOL
# 3    01M458                          FORSYTH SATELLITE ACADEMY
# 4    01M509                            MARTA VALLE HIGH SCHOOL
# 5    01M515            LOWER EAST SIDE PREPARATORY HIGH SCHOOL
# 6    01M539  NEW EXPLORATIONS INTO SCIENCE, TECHNOLOGY AND ...
# 7    01M650                               CASCADES HIGH SCHOOL
# 8    01M696                     BARD HIGH SCHOOL EARLY COLLEGE
# 9    02M047  47 THE AMERICAN SIGN LANGUAGE AND ENGLISH SECO...
# 10   02M288                       FOOD AND FINANCE HIGH SCHOOL
# 11   02M294                               ESSEX STREET ACADEMY
# 12   02M296              HIGH SCHOOL OF HOSPITALITY MANAGEMENT
# 13   02M298                                   PACE HIGH SCHOOL
# ...

# %%
df.head()
# Out:
#       DBN                                     School Name  \
# 0  01M292  Henry Street School for International Studies
# 1  01M448            University Neighborhood High School
# 2  01M450                East Side Community High School
# 3  01M458                   SATELLITE ACADEMY FORSYTH ST
# 4  01M509                               CMSP HIGH SCHOOL
#
#    Number of Test Takers  Critical Reading Mean  Mathematics Mean  \
# 0                   31.0                  391.0             425.0
# 1                   60.0                  394.0             419.0
# 2                   69.0                  418.0             431.0
# 3                   26.0                  385.0             370.0
# 4                    NaN                    NaN               NaN
#
#    Writing Mean
# 0         385.0
# 1         387.0
# 2         402.0
# 3         378.0
# 4           NaN

# %%
df
# Out:
#                                            SCHOOL NAME Num of SAT Test Takers  \
# 0        HENRY STREET SCHOOL FOR INTERNATIONAL STUDIES                     29
# 1                  UNIVERSITY NEIGHBORHOOD HIGH SCHOOL                     91
# 2                           EAST SIDE COMMUNITY SCHOOL                     70
# 3                            FORSYTH SATELLITE ACADEMY                      7
# 4                              MARTA VALLE HIGH SCHOOL                     44
# 5              LOWER EAST SIDE PREPARATORY HIGH SCHOOL                    112
# 6    NEW EXPLORATIONS INTO SCIENCE, TECHNOLOGY AND ...                    159
# 7                                 CASCADES HIGH SCHOOL                     18
# 8                       BARD HIGH SCHOOL EARLY COLLEGE                    130
# 9    47 THE AMERICAN SIGN LANGUAGE AND ENGLISH SECO...                     16
# 10                        FOOD AND FINANCE HIGH SCHOOL                     62
# ...

# %%
df2.head()
# Out:
#                                      SCHOOL NAME Num of SAT Test Takers  \
# 0  HENRY STREET SCHOOL FOR INTERNATIONAL STUDIES                     29
# 1            UNIVERSITY NEIGHBORHOOD HIGH SCHOOL                     91
# 2                     EAST SIDE COMMUNITY SCHOOL                     70
# 3                      FORSYTH SATELLITE ACADEMY                      7
# 4                        MARTA VALLE HIGH SCHOOL                     44
#
#   SAT Critical Reading Avg. Score SAT Math Avg. Score SAT Writing Avg. Score
# 0                             355                 404                    363
# 1                             383                 423                    366
# 2                             377                 402                    370
# 3                             414                 401                    359
# 4                             390                 433                    384

# %%
df2
# Out:
#                                            SCHOOL NAME Num of SAT Test Takers  \
# 0        HENRY STREET SCHOOL FOR INTERNATIONAL STUDIES                     29
# 1                  UNIVERSITY NEIGHBORHOOD HIGH SCHOOL                     91
# 2                           EAST SIDE COMMUNITY SCHOOL                     70
# 3                            FORSYTH SATELLITE ACADEMY                      7
# 4                              MARTA VALLE HIGH SCHOOL                     44
# 5              LOWER EAST SIDE PREPARATORY HIGH SCHOOL                    112
# 6    NEW EXPLORATIONS INTO SCIENCE, TECHNOLOGY AND ...                    159
# 7                                 CASCADES HIGH SCHOOL                     18
# 8                       BARD HIGH SCHOOL EARLY COLLEGE                    130
# 9    47 THE AMERICAN SIGN LANGUAGE AND ENGLISH SECO...                     16
# 10                        FOOD AND FINANCE HIGH SCHOOL                     62
# ...

# %%
df3=pd.merge(df.head(),df2.head(),how='outer')

# %%
df3
# Out:
#       DBN                                     School Name  \
# 0  01M292  Henry Street School for International Studies
# 1  01M448            University Neighborhood High School
# 2  01M450                East Side Community High School
# 3  01M458                   SATELLITE ACADEMY FORSYTH ST
# 4  01M509                               CMSP HIGH SCHOOL
#
#    Number of Test Takers  Critical Reading Mean  Mathematics Mean  \
# 0                   31.0                  391.0             425.0
# 1                   60.0                  394.0             419.0
# 2                   69.0                  418.0             431.0
# 3                   26.0                  385.0             370.0
# 4                    NaN                    NaN               NaN
#
#    Writing Mean                                    SCHOOL NAME  \
# 0         385.0  HENRY STREET SCHOOL FOR INTERNATIONAL STUDIES
# 1         387.0            UNIVERSITY NEIGHBORHOOD HIGH SCHOOL
# ...

# %%
df3.plot.bar()

# %%
# %matplotlib inline

# %%
df3.plot.bar()
